# %% [markdown]
# # 1.import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
pwd
# Out:
# 'C:\\Users\\pc'

# %% [markdown]
# # 2.Loading The Dataset

# %%
ak=pd.read_csv('abalone.csv')
ak
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ak.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
ak['Age']=ak['Rings']+1.5
ak.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %%
ak.info
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings   Age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# ...

# %%
ak.shape
# Out:
# (4177, 10)

# %% [markdown]
# # 3.Perform Below Visualizations.

# %%
#univariate analysis
sns.displot(ak['Whole weight'])

# %%
sns.distplot(ak.Age)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
ak.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
plt.pie(ak.Sex.value_counts(),[0,0.2,0.1],labels=['M','F','I'],autopct="%1.1f%%",colors=['pink','violet','red'])
plt.title('Sex')
# Out:
# Text(0.5, 1.0, 'Sex')

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lineplot(ak.Age,ak['Height'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
sns.barplot(ak.Age,ak['Sex'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # Multivariate Analysis¶

# %%
plt.figure(figsize=(10,8))
sns.heatmap(ak.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=ak,aspect=.85,hue='Sex')

# %% [markdown]
# # 4.Descriptive statistics¶

# %%
ak.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %%
ak.Diameter.median()
# Out:
# 0.425

# %%
ak['Shell weight'].median()
# Out:
# 0.234

# %%
ak.Length.median()
# Out:
# 0.545

# %% [markdown]
# # 5.Handling missing values

# %%
ak.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# Age               False
# dtype: bool

# %%
ak.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# Age               0
# dtype: int64

# %% [markdown]
# # 6.Finding and replacing the outliers

# %%
sns.boxplot(ak.Diameter)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
q1=ak.Diameter.quantile(0.25)
q3=ak.Diameter.quantile(0.75)
print(q1)
print(q3)
# Out:
# 0.35
# 0.48

# %%
iqr=q3-q1
iqr
# Out:
# 0.13

# %%
ll=q1-1.5*iqr
ll
# Out:
# 0.15499999999999997

# %%
ak.Diameter.median()
# Out:
# 0.425

# %%
ak['Diameter']=np.where(ak['Diameter']<ll,0.425,ak['Diameter'])

# %%
sns.boxplot(ak.Diameter)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(ak['Shell weight'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell weight'>

# %%
Q1=ak['Shell weight'].quantile(0.25)
Q3=ak['Shell weight'].quantile(0.75)
print(Q1)
print(Q3)
# Out:
# 0.13
# 0.329

# %%
IQR=Q3-Q1
IQR
# Out:
# 0.199

# %%
UL=Q3+1.5*IQR
UL
# Out:
# 0.6275

# %%
ak['Shell weight'].median()
# Out:
# 0.234

# %%
ak['Shell weight']=np.where(ak['Shell weight']>0.6,0.23,ak['Shell weight'])

# %%
sns.boxplot(ak['Shell weight'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell weight'>

# %%
sns.boxplot(ak.Length)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
qq1=ak.Length.quantile(0.25)
qq3=ak.Length.quantile(0.75)
print(qq1)
print(qq3)
# Out:
# 0.45
# 0.615

# %%
Iqr=qq3-qq1
Iqr
# Out:
# 0.16499999999999998

# %%
LL=qq1-1.5*Iqr
LL
# Out:
# 0.20250000000000004

# %%
ak.Length.median()
# Out:
# 0.545

# %%
ak['Length']=np.where(ak['Length']<0.25,0.54,ak['Length'])

# %%
sns.boxplot(ak.Length)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(ak.Height)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
Qua1=ak['Height'].quantile(0.25)
Qua3=ak['Height'].quantile(0.75)
print(Qua1)
print(Qua3)
# Out:
# 0.115
# 0.165

# %%
iQR=Qua3-Qua1
iQR
# Out:
# 0.05

# %%
upp=Qua3+1.5*iQR
upp
# Out:
# 0.24000000000000002

# %%
ak['Height'].median()
# Out:
# 0.14

# %%
ak['Height']=np.where(ak['Height']>upp,0.14,ak['Height'])

# %%
sns.boxplot(ak.Height)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
quart1=ak.Height.quantile(0.25)
quart3=ak.Height.quantile(0.75)
print(quart1)
print(quart3)
# Out:
# 0.115
# 0.165

# %%
Iqqr=quart3-quart1
Iqqr
# Out:
# 0.05

# %%
low=Qua1-1.5*iQR
low
# Out:
# 0.039999999999999994

# %%
ak['Height']=np.where(ak['Height']<0.04,0.14,ak['Height'])

# %%
sns.boxplot(ak.Height)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sns.pairplot(data=ak)

# %% [markdown]
# # 7.Encoding categorical columns

# %%
ak.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings   Age
# 0         0.150     15  16.5
# 1         0.070      7   8.5
# 2         0.210      9  10.5
# 3         0.155     10  11.5
# 4         0.055      7   8.5

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
ak.Sex=le.fit_transform(ak.Sex)

# %%
ak.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings   Age
# 0          0.1010         0.150     15  16.5
# 1          0.0485         0.070      7   8.5
# 2          0.1415         0.210      9  10.5
# 3          0.1140         0.155     10  11.5
# 4          0.0395         0.055      7   8.5

# %%
ak.Sex.value_counts()
# Out:
# 2    1528
# 1    1342
# 0    1307
# Name: Sex, dtype: int64

# %% [markdown]
# # 8.Split dependant and independant columns(x and y split)

# %%
ak.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings   Age
# 0          0.1010         0.150     15  16.5
# 1          0.0485         0.070      7   8.5
# 2          0.1415         0.210      9  10.5
# 3          0.1140         0.155     10  11.5
# 4          0.0395         0.055      7   8.5

# %%
y=ak.Age
y.head()
# Out:
# 0    16.5
# 1     8.5
# 2    10.5
# 3    11.5
# 4     8.5
# Name: Age, dtype: float64

# %%
X=ak.drop(columns=['Age'],axis=1)
X.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %% [markdown]
# # 9.Data Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()

# %%
xsc=pd.DataFrame(sc.fit_transform(X),columns=X.columns)
xsc.head()
# Out:
#    Sex    Length  Diameter  Height  Whole weight  Shucked weight  \
# 0  1.0  0.362832  0.424242   0.275      0.181335        0.150303
# 1  1.0  0.176991  0.222222   0.250      0.079157        0.066241
# 2  0.0  0.495575  0.535354   0.475      0.239065        0.171822
# 3  1.0  0.336283  0.424242   0.425      0.182044        0.144250
# 4  0.5  0.141593  0.202020   0.200      0.071897        0.059516
#
#    Viscera weight  Shell weight     Rings
# 0        0.132324      0.248120  0.500000
# 1        0.063199      0.114453  0.214286
# 2        0.185648      0.348371  0.285714
# 3        0.149440      0.256475  0.321429
# 4        0.051350      0.089390  0.214286

# %% [markdown]
# # 10.Train and Test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(xsc,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#       Sex    Length  Diameter  Height  Whole weight  Shucked weight  \
# 1376  1.0  0.654867  0.717172   0.675      0.453161        0.383658
# 1225  0.5  0.168142  0.202020   0.225      0.070303        0.069939
# 2722  0.5  0.221239  0.242424   0.275      0.080574        0.063215
# 3387  1.0  0.522124  0.515152   0.525      0.308482        0.203430
# 2773  0.0  0.584071  0.626263   0.525      0.348681        0.315400
# ...   ...       ...       ...     ...           ...             ...
# 1033  1.0  0.707965  0.747475   0.725      0.573756        0.446200
# 3264  0.0  0.716814  0.696970   0.500      0.413848        0.362811
# 1653  1.0  0.610619  0.595960   0.525      0.338941        0.310693
# 2607  0.0  0.663717  0.676768   0.625      0.398442        0.320108
# 2732  0.5  0.283186  0.343434   0.350      0.114751        0.088433
#
#       Viscera weight  Shell weight     Rings
# 1376        0.313364      0.649123  0.321429
# 1225        0.048058      0.081036  0.142857
# ...

# %%
X_test
# Out:
#       Sex    Length  Diameter  Height  Whole weight  Shucked weight  \
# 668   1.0  0.530973  0.545455   0.575      0.324243        0.185945
# 1580  0.5  0.442478  0.494949   0.400      0.217461        0.174849
# 3784  1.0  0.654867  0.656566   0.575      0.443953        0.353732
# 463   0.5  0.513274  0.020202   0.075      0.018594        0.013786
# 2615  1.0  0.699115  0.696970   0.675      0.534266        0.452253
# ...   ...       ...       ...     ...           ...             ...
# 1052  1.0  0.911504  0.898990   0.900      0.814592        0.676530
# 3439  0.5  0.336283  0.393939   0.425      0.160793        0.140551
# 1174  0.0  0.681416  0.686869   0.500      0.408890        0.343309
# 2210  1.0  0.725664  0.707071   0.800      0.576766        0.326496
# 2408  0.5  0.654867  0.666667   0.650      0.427129        0.322461
#
#       Viscera weight  Shell weight     Rings
# 668         0.319289      0.557226  0.428571
# 1580        0.187623      0.320802  0.250000
# ...

# %%
y_train
# Out:
# 1376    11.5
# 1225     6.5
# 2722     8.5
# 3387    19.5
# 2773    12.5
#         ...
# 1033    11.5
# 3264    13.5
# 1653    11.5
# 2607    10.5
# 2732     9.5
# Name: Age, Length: 2923, dtype: float64

# %%
y_test
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
#         ...
# 1052    13.5
# 3439     9.5
# 1174    10.5
# 2210    19.5
# 2408    16.5
# Name: Age, Length: 1254, dtype: float64

# %% [markdown]
# # 11.Build the Model

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_model=PolynomialFeatures(degree=6)

# %% [markdown]
# # 12.Train the Model

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
poly_x_values=poly_model.fit_transform(X)

# %%
poly_model.fit(poly_x_values,y)
# Out:
# PolynomialFeatures(degree=6)

# %%
reg_mod=LinearRegression()
reg_mod.fit(poly_x_values,y)
# Out:
# LinearRegression()

# %% [markdown]
# # 13.Test the Model¶

# %%
pred=model.predict(X_test)
pred
# Out:
# array([14.5,  9.5, 12.5, ..., 10.5, 19.5, 16.5])

# %%
y_pred=reg_mod.predict(poly_x_values)
y_pred
# Out:
# array([16.4999998 ,  8.5       , 10.5       , ..., 10.50000001,
#        11.50000001, 13.49999999])

# %%
print(y_pred)
# Out:
# [16.4999998   8.5        10.5        ... 10.50000001 11.50000001
#  13.49999999]

# %%
y_pred.shape
# Out:
# (4177,)

# %% [markdown]
# # 14.Measure the performance using metrics

# %%
cmp=pd.DataFrame({'Actual':y_test,'Predicted':pred})
cmp.head()
# Out:
#       Actual  Predicted
# 668     14.5       14.5
# 1580     9.5        9.5
# 3784    12.5       12.5
# 463      6.5        6.5
# 2615    13.5       13.5

# %%
from sklearn import metrics

# %%
print(metrics.r2_score(y_test,pred))
# Out:
# 1.0

# %%
print(metrics.r2_score(y,y_pred))
# Out:
# 1.0

# %%
mse2=metrics.mean_squared_error(y,y_pred)
mse2
# Out:
# 2.762813042842692e-16

# %%
mse1=metrics.mean_squared_error(y_test,pred)
mse1
# Out:
# 4.788283784431059e-27

# %%
import math
rmse1=math.sqrt(mse1)
rmse1

# %%
rmse2=math.sqrt(0.7)  
rmse2
